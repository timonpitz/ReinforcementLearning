# %%
#!pip install numpy
#!pip install gym
#!pip install matplotlib
import numpy as np
import gym
import matplotlib.pyplot as plt
import pickle

# %%
#Spaces erstellen um stetige Werte für Position und Geschwindigkeit in diskrete Werte einzuordnen
pos_buckets = np.linspace(-1.2, 0.6, 20)
vel_buckets = np.linspace(-0.07, 0.07, 20)

# %%
#Status des Objektes wird in diskreten Werten zurückgegeben
def toDiscreteStates(obs):
    pos, vel = obs
    
    #stetige Werte von Position und Geschwindigkeit werden in den oben erstellten Spaces eingeordnet
    pos_disc = np.digitize(pos, pos_buckets)
    vel_disc = np.digitize(vel, vel_buckets)
    
    return(pos_disc, vel_disc)

# %%
#Funktion um die Aktion herauszufinden die wahrscheinlich die höchste Belohnung ergibt
def max_action(Q, obs, actions=[0,1,2]):
    state = toDiscreteStates(obs)
    values = []
    for a in actions:
        values.append(Q[state, a]) #Alle Werte der Bewertungsfunktion werden in einer Liste zusammengefasst
    
    action = np.argmax(values) #Maximaler Wert in der Bewertungsfunktion
    
    return action

# %%
env = gym.make('MountainCar-v0') #Umgebung generieren
env._max_episode_steps = 1000 #Maximale steps bis das Spiel abbricht, wenn es nicht geschafft wird
n_games = 50000
alpha = 0.1
gamma = 0.99
eps = 1.0

# %%
#2-Dimensionale Liste mit allen möglichen Status
states = [] 
for pos in range(21):
    for vel in range(21):
        states.append((pos,vel))

# %%
#Q-Tabelle als Dictionary der Form 441x3 mit allen Kombinationen aus Status und Aktionen
Q = {} 
for state in states:
    for action in [0,1,2]:
        Q[state, action] = 0

# %%
#Funktion um Q-Tabelle lokal abzuspeichern
def saveQ():
    with open('obj/Qtable.pkl', 'wb') as f:
        pickle.dump(Q, f, pickle.HIGHEST_PROTOCOL)

# %%
#Funktion um lokale Q-Tabelle zu laden und so an vorheriges lernen anknuepfen zu koennen
def loadQ():
    with open('obj/Qtable.pkl', 'rb') as f:
        return pickle.load(f)

# %%
#Die Q-Tabelle wird um neue Belohnungswerte aktualisiert
#Hier findet das eigentliche Lernen statt
def updateQ(obs, action, reward, new_obs, new_action):
    state = toDiscreteStates(obs)
    new_state = toDiscreteStates(new_obs)
    Q[state, action] = Q[state, action] + alpha*(reward + gamma*Q[new_state, new_action] - Q[state, action])

# %%
#Spielt mit der gespeicherten Q-Tabelle 10 Spiele um den Lernfortschritt darzustellen
def show_result():
    Q = loadQ() #lokal gespeicherte Q-Tabelle wird geladen
    new_eps = 0.01 #Epsilon wird direkt am Anfang auf den Minimalwert gesetzt da hier nicht dazu gelernt werden soll
    for i in range(10):
        done = False
        obs = env.reset()
        while not done:
            if np.random.random() < new_eps:
                action = np.random.choice([0,1,2])
            else:
                action = max_action(Q, obs)
        
            new_obs, reward, done, info = env.step(action)
            new_action = max_action(Q, new_obs)
            updateQ(obs, action, reward, new_obs, new_action)
            obs = new_obs
            env.render() #Spiel wird gerendert und dem Nutzer angezeigt

# %%
#In diesem Panel wird das eigentliche Spielen und Lernen ausgefuehrt

score = 0 #Belohnung eines einzelnen Spieldurchlaufes
total_rewards = np.zeros(n_games) #Belohnungen aller Durchlaeufe

#Q = loadQ()

for i in range(n_games):
    done = False
    obs = env.reset() #Beobachtung zum Startzeitpunkt
    if i % 100 == 0 and i>0:
        print('episode ', i, 'score ', score, 'eps ', eps)
    score = 0
    while not done:
        #Epsilon-Greedy-Algorithmus
        #Mit einer wahrscheinlichkeit von Epsilon wird eine zufällige Aktion ausgeführt
        if np.random.random() < eps:
            action = np.random.choice([0,1,2])
        #Sonst wird die Aktion ausgewählt die wahrscheinlich die beste Belohnung ergibt
        else:
            action = max_action(Q, obs)
        
        #Die oben ausgewaehlte Aktion wird ausgeführt
        #Die neue Beobachtung des Status, die Belohnung und die Information ob das Spiel vorbei ist werden zurueckgegeben
        new_obs, reward, done, info = env.step(action)
        score += reward
        new_action = max_action(Q, new_obs)
        updateQ(obs, action, reward, new_obs, new_action)
        obs = new_obs
    total_rewards[i] = score
    #Epsilon wird nach jedem Spiel so verringert, dass es nach der Haelfte der Zeit den Minimalwert erreicht
    if eps > 0.01:
        eps = eps - 2/n_games
    else:
        eps = 0.01
# Out:
# episode  100 score  -1000.0 eps  0.995999999999996
# episode  200 score  -1000.0 eps  0.991999999999992
# episode  300 score  -1000.0 eps  0.987999999999988
# episode  400 score  -1000.0 eps  0.983999999999984
# episode  500 score  -1000.0 eps  0.97999999999998
# episode  600 score  -1000.0 eps  0.975999999999976
# episode  700 score  -1000.0 eps  0.971999999999972
# episode  800 score  -1000.0 eps  0.967999999999968
# episode  900 score  -1000.0 eps  0.963999999999964
# episode  1000 score  -1000.0 eps  0.95999999999996
# episode  1100 score  -1000.0 eps  0.955999999999956
# episode  1200 score  -1000.0 eps  0.951999999999952
# episode  1300 score  -1000.0 eps  0.947999999999948
# episode  1400 score  -1000.0 eps  0.943999999999944
# episode  1500 score  -1000.0 eps  0.93999999999994
# episode  1600 score  -1000.0 eps  0.935999999999936
# episode  1700 score  -1000.0 eps  0.931999999999932
# episode  1800 score  -1000.0 eps  0.927999999999928
# episode  1900 score  -1000.0 eps  0.923999999999924
# episode  2000 score  -1000.0 eps  0.91999999999992
# episode  2100 score  -1000.0 eps  0.915999999999916
# episode  2200 score  -1000.0 eps  0.911999999999912
# episode  2300 score  -1000.0 eps  0.907999999999908
# episode  2400 score  -1000.0 eps  0.903999999999904
# episode  2500 score  -741.0 eps  0.8999999999999
# episode  2600 score  -1000.0 eps  0.895999999999896
# episode  2700 score  -796.0 eps  0.891999999999892
# episode  2800 score  -1000.0 eps  0.887999999999888
# episode  2900 score  -1000.0 eps  0.883999999999884
# episode  3000 score  -1000.0 eps  0.87999999999988
# episode  3100 score  -1000.0 eps  0.875999999999876
# episode  3200 score  -1000.0 eps  0.871999999999872
# episode  3300 score  -1000.0 eps  0.867999999999868
# episode  3400 score  -761.0 eps  0.863999999999864
# episode  3500 score  -1000.0 eps  0.85999999999986
# episode  3600 score  -837.0 eps  0.855999999999856
# episode  3700 score  -1000.0 eps  0.851999999999852
# episode  3800 score  -1000.0 eps  0.847999999999848
# episode  3900 score  -880.0 eps  0.843999999999844
# episode  4000 score  -1000.0 eps  0.83999999999984
# episode  4100 score  -1000.0 eps  0.835999999999836
# episode  4200 score  -1000.0 eps  0.831999999999832
# episode  4300 score  -1000.0 eps  0.827999999999828
# episode  4400 score  -684.0 eps  0.823999999999824
# episode  4500 score  -1000.0 eps  0.81999999999982
# episode  4600 score  -1000.0 eps  0.815999999999816
# episode  4700 score  -1000.0 eps  0.811999999999812
# episode  4800 score  -598.0 eps  0.807999999999808
# episode  4900 score  -1000.0 eps  0.803999999999804
# episode  5000 score  -1000.0 eps  0.7999999999998
# episode  5100 score  -940.0 eps  0.795999999999796
# episode  5200 score  -1000.0 eps  0.791999999999792
# episode  5300 score  -1000.0 eps  0.787999999999788
# episode  5400 score  -928.0 eps  0.783999999999784
# episode  5500 score  -1000.0 eps  0.77999999999978
# episode  5600 score  -1000.0 eps  0.775999999999776
# episode  5700 score  -534.0 eps  0.771999999999772
# episode  5800 score  -1000.0 eps  0.767999999999768
# episode  5900 score  -786.0 eps  0.763999999999764
# episode  6000 score  -1000.0 eps  0.75999999999976
# episode  6100 score  -1000.0 eps  0.755999999999756
# episode  6200 score  -1000.0 eps  0.751999999999752
# episode  6300 score  -660.0 eps  0.747999999999748
# episode  6400 score  -1000.0 eps  0.743999999999744
# episode  6500 score  -559.0 eps  0.73999999999974
# episode  6600 score  -566.0 eps  0.735999999999736
# episode  6700 score  -561.0 eps  0.731999999999732
# episode  6800 score  -1000.0 eps  0.727999999999728
# episode  6900 score  -701.0 eps  0.723999999999724
# episode  7000 score  -1000.0 eps  0.71999999999972
# episode  7100 score  -479.0 eps  0.715999999999716
# episode  7200 score  -355.0 eps  0.711999999999712
# episode  7300 score  -582.0 eps  0.707999999999708
# episode  7400 score  -357.0 eps  0.703999999999704
# episode  7500 score  -333.0 eps  0.6999999999997
# episode  7600 score  -828.0 eps  0.695999999999696
# episode  7700 score  -1000.0 eps  0.691999999999692
# episode  7800 score  -985.0 eps  0.687999999999688
# episode  7900 score  -239.0 eps  0.683999999999684
# episode  8000 score  -1000.0 eps  0.67999999999968
# episode  8100 score  -461.0 eps  0.675999999999676
# episode  8200 score  -898.0 eps  0.671999999999672
# episode  8300 score  -333.0 eps  0.667999999999668
# episode  8400 score  -709.0 eps  0.663999999999664
# episode  8500 score  -441.0 eps  0.65999999999966
# episode  8600 score  -316.0 eps  0.655999999999656
# episode  8700 score  -582.0 eps  0.651999999999652
# episode  8800 score  -353.0 eps  0.647999999999648
# episode  8900 score  -240.0 eps  0.643999999999644
# episode  9000 score  -842.0 eps  0.63999999999964
# episode  9100 score  -562.0 eps  0.635999999999636
# episode  9200 score  -562.0 eps  0.631999999999632
# episode  9300 score  -328.0 eps  0.627999999999628
# episode  9400 score  -493.0 eps  0.623999999999624
# episode  9500 score  -465.0 eps  0.61999999999962
# episode  9600 score  -241.0 eps  0.615999999999616
# episode  9700 score  -1000.0 eps  0.611999999999612
# episode  9800 score  -279.0 eps  0.607999999999608
# episode  9900 score  -747.0 eps  0.603999999999604
# episode  28600 score  -137.0 eps  0.01
# episode  28700 score  -148.0 eps  0.01
# episode  28800 score  -134.0 eps  0.01
# episode  28900 score  -138.0 eps  0.01
# episode  29000 score  -134.0 eps  0.01
# episode  29100 score  -137.0 eps  0.01
# episode  29200 score  -139.0 eps  0.01
# episode  29300 score  -140.0 eps  0.01
# episode  29400 score  -139.0 eps  0.01
# episode  29500 score  -130.0 eps  0.01
# episode  29600 score  -137.0 eps  0.01
# episode  29700 score  -139.0 eps  0.01
# episode  29800 score  -138.0 eps  0.01
# episode  29900 score  -136.0 eps  0.01
# episode  30000 score  -141.0 eps  0.01
# episode  30100 score  -132.0 eps  0.01
# episode  30200 score  -139.0 eps  0.01
# episode  30300 score  -135.0 eps  0.01
# episode  30400 score  -136.0 eps  0.01
# episode  30500 score  -145.0 eps  0.01
# episode  30600 score  -138.0 eps  0.01
# episode  30700 score  -150.0 eps  0.01
# episode  30800 score  -141.0 eps  0.01
# episode  30900 score  -150.0 eps  0.01
# episode  31000 score  -136.0 eps  0.01
# episode  31100 score  -145.0 eps  0.01
# episode  31200 score  -142.0 eps  0.01
# episode  31300 score  -149.0 eps  0.01
# episode  31400 score  -156.0 eps  0.01
# episode  31500 score  -159.0 eps  0.01
# episode  31600 score  -153.0 eps  0.01
# episode  31700 score  -139.0 eps  0.01
# episode  31800 score  -142.0 eps  0.01
# episode  31900 score  -143.0 eps  0.01
# episode  32000 score  -142.0 eps  0.01
# episode  32100 score  -141.0 eps  0.01
# episode  32200 score  -140.0 eps  0.01
# episode  32300 score  -140.0 eps  0.01
# episode  32400 score  -145.0 eps  0.01
# episode  32500 score  -159.0 eps  0.01
# episode  32600 score  -140.0 eps  0.01
# episode  32700 score  -206.0 eps  0.01
# episode  32800 score  -153.0 eps  0.01
# episode  32900 score  -216.0 eps  0.01
# episode  33000 score  -216.0 eps  0.01
# episode  33100 score  -133.0 eps  0.01
# episode  33200 score  -145.0 eps  0.01
# episode  33300 score  -145.0 eps  0.01
# episode  33400 score  -137.0 eps  0.01
# episode  33500 score  -130.0 eps  0.01
# episode  33600 score  -142.0 eps  0.01
# episode  33700 score  -135.0 eps  0.01
# episode  33800 score  -130.0 eps  0.01
# episode  33900 score  -134.0 eps  0.01
# episode  34000 score  -130.0 eps  0.01
# episode  34100 score  -141.0 eps  0.01
# episode  34200 score  -135.0 eps  0.01
# episode  34300 score  -142.0 eps  0.01
# episode  34400 score  -136.0 eps  0.01
# episode  34500 score  -140.0 eps  0.01
# episode  34600 score  -138.0 eps  0.01
# episode  34700 score  -137.0 eps  0.01
# episode  34800 score  -133.0 eps  0.01
# episode  34900 score  -139.0 eps  0.01
# episode  35000 score  -135.0 eps  0.01
# episode  35100 score  -137.0 eps  0.01
# episode  35200 score  -135.0 eps  0.01
# episode  35300 score  -132.0 eps  0.01
# episode  35400 score  -134.0 eps  0.01
# episode  35500 score  -133.0 eps  0.01
# episode  35600 score  -141.0 eps  0.01
# episode  35700 score  -136.0 eps  0.01
# episode  35800 score  -137.0 eps  0.01
# episode  35900 score  -134.0 eps  0.01
# episode  36000 score  -137.0 eps  0.01
# episode  36100 score  -142.0 eps  0.01
# episode  36200 score  -134.0 eps  0.01
# episode  36300 score  -137.0 eps  0.01
# episode  36400 score  -137.0 eps  0.01
# episode  36500 score  -132.0 eps  0.01
# episode  36600 score  -134.0 eps  0.01
# episode  36700 score  -139.0 eps  0.01
# episode  36800 score  -138.0 eps  0.01
# episode  36900 score  -136.0 eps  0.01
# episode  37000 score  -136.0 eps  0.01
# episode  37100 score  -133.0 eps  0.01
# episode  37200 score  -147.0 eps  0.01
# episode  37300 score  -144.0 eps  0.01
# episode  37400 score  -146.0 eps  0.01
# episode  37500 score  -125.0 eps  0.01
# episode  37600 score  -120.0 eps  0.01
# episode  37700 score  -138.0 eps  0.01
# episode  37800 score  -142.0 eps  0.01
# episode  37900 score  -144.0 eps  0.01
# episode  38000 score  -137.0 eps  0.01
# episode  38100 score  -144.0 eps  0.01
# episode  38200 score  -136.0 eps  0.01
# episode  38300 score  -209.0 eps  0.01
# episode  38400 score  -144.0 eps  0.01
# episode  38500 score  -143.0 eps  0.01
# episode  38600 score  -137.0 eps  0.01
# episode  38700 score  -142.0 eps  0.01
# episode  38800 score  -158.0 eps  0.01
# episode  38900 score  -121.0 eps  0.01
# episode  39000 score  -197.0 eps  0.01
# episode  39100 score  -161.0 eps  0.01
# episode  39200 score  -152.0 eps  0.01
# episode  39300 score  -168.0 eps  0.01
# episode  39400 score  -209.0 eps  0.01
# episode  39500 score  -150.0 eps  0.01
# episode  39600 score  -396.0 eps  0.01
# episode  39700 score  -219.0 eps  0.01
# episode  39800 score  -133.0 eps  0.01
# episode  39900 score  -144.0 eps  0.01
# episode  40000 score  -138.0 eps  0.01
# episode  40100 score  -134.0 eps  0.01
# episode  40200 score  -137.0 eps  0.01
# episode  40300 score  -146.0 eps  0.01
# episode  40400 score  -140.0 eps  0.01
# episode  40500 score  -137.0 eps  0.01
# episode  40600 score  -145.0 eps  0.01
# episode  40700 score  -137.0 eps  0.01
# episode  40800 score  -140.0 eps  0.01
# episode  40900 score  -138.0 eps  0.01
# episode  41000 score  -139.0 eps  0.01
# episode  41100 score  -142.0 eps  0.01
# episode  41200 score  -139.0 eps  0.01
# episode  41300 score  -145.0 eps  0.01
# episode  41400 score  -146.0 eps  0.01
# episode  41500 score  -134.0 eps  0.01
# episode  41600 score  -139.0 eps  0.01
# episode  41700 score  -133.0 eps  0.01
# episode  41800 score  -132.0 eps  0.01
# episode  41900 score  -136.0 eps  0.01
# episode  42000 score  -144.0 eps  0.01
# episode  42100 score  -143.0 eps  0.01
# episode  42200 score  -199.0 eps  0.01
# episode  42300 score  -143.0 eps  0.01
# episode  42400 score  -144.0 eps  0.01
# episode  42500 score  -301.0 eps  0.01
# episode  42600 score  -133.0 eps  0.01
# episode  42700 score  -132.0 eps  0.01
# episode  42800 score  -140.0 eps  0.01
# episode  42900 score  -142.0 eps  0.01
# episode  43000 score  -163.0 eps  0.01
# episode  43100 score  -219.0 eps  0.01
# episode  43200 score  -140.0 eps  0.01
# episode  43300 score  -146.0 eps  0.01
# episode  43400 score  -151.0 eps  0.01
# episode  43500 score  -149.0 eps  0.01
# episode  43600 score  -147.0 eps  0.01
# episode  43700 score  -139.0 eps  0.01
# episode  43800 score  -140.0 eps  0.01
# episode  43900 score  -143.0 eps  0.01
# episode  44000 score  -146.0 eps  0.01
# episode  44100 score  -245.0 eps  0.01
# episode  44200 score  -138.0 eps  0.01
# episode  44300 score  -143.0 eps  0.01
# episode  44400 score  -155.0 eps  0.01
# episode  44500 score  -140.0 eps  0.01
# episode  44600 score  -143.0 eps  0.01
# episode  44700 score  -143.0 eps  0.01
# episode  44800 score  -142.0 eps  0.01
# episode  44900 score  -145.0 eps  0.01
# episode  45000 score  -146.0 eps  0.01
# episode  45100 score  -151.0 eps  0.01
# episode  45200 score  -143.0 eps  0.01
# episode  45300 score  -150.0 eps  0.01
# episode  45400 score  -147.0 eps  0.01
# episode  45500 score  -145.0 eps  0.01
# episode  45600 score  -121.0 eps  0.01
# episode  45700 score  -141.0 eps  0.01
# episode  45800 score  -124.0 eps  0.01
# episode  45900 score  -126.0 eps  0.01
# episode  46000 score  -138.0 eps  0.01
# episode  46100 score  -148.0 eps  0.01
# episode  46200 score  -141.0 eps  0.01
# episode  46300 score  -156.0 eps  0.01
# episode  46400 score  -150.0 eps  0.01
# episode  46500 score  -152.0 eps  0.01
# episode  46600 score  -158.0 eps  0.01
# episode  46700 score  -150.0 eps  0.01
# episode  46800 score  -156.0 eps  0.01
# episode  46900 score  -142.0 eps  0.01
# episode  47000 score  -147.0 eps  0.01
# episode  47100 score  -157.0 eps  0.01
# episode  47200 score  -137.0 eps  0.01
# episode  47300 score  -215.0 eps  0.01
# episode  47400 score  -145.0 eps  0.01
# episode  47500 score  -200.0 eps  0.01
# episode  47600 score  -201.0 eps  0.01
# episode  47700 score  -147.0 eps  0.01
# episode  47800 score  -220.0 eps  0.01
# episode  47900 score  -210.0 eps  0.01
# episode  48000 score  -138.0 eps  0.01
# episode  48100 score  -144.0 eps  0.01
# episode  48200 score  -209.0 eps  0.01
# episode  48300 score  -146.0 eps  0.01
# episode  48400 score  -143.0 eps  0.01
# episode  48500 score  -136.0 eps  0.01
# episode  48600 score  -143.0 eps  0.01
# episode  48700 score  -152.0 eps  0.01
# episode  48800 score  -142.0 eps  0.01
# episode  48900 score  -148.0 eps  0.01
# episode  49000 score  -142.0 eps  0.01
# episode  49100 score  -147.0 eps  0.01
# episode  49200 score  -143.0 eps  0.01
# episode  49300 score  -139.0 eps  0.01
# episode  49400 score  -136.0 eps  0.01
# episode  49500 score  -151.0 eps  0.01
# episode  49600 score  -153.0 eps  0.01
# episode  49700 score  -132.0 eps  0.01
# episode  49800 score  -338.0 eps  0.01
# episode  49900 score  -212.0 eps  0.01

# %%
saveQ()
#show_result()
mean_rewards = np.zeros(n_games)
for r in range(n_games):
    mean_rewards[r] = np.mean(total_rewards[max(0, r-50):(r+1)])
plt.plot(mean_rewards)
plt.savefig('mountaincar.png')
